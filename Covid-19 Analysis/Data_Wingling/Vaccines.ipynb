# %% [markdown]
# # Import Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
df=pd.read_csv("vaccination-data.csv")

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING    8/30/2021
# 1         Albania  ALB       EURO        OWID    8/30/2021
# 2         Algeria  DZA       AFRO   REPORTING    8/23/2021
# 3  American Samoa  ASM       WPRO   REPORTING    8/20/2021
# 4         Andorra  AND       EURO        OWID    8/15/2021
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0             1979652                       773002.0
# 1             1458048                       824170.0
# 2             4146091                      3421279.0
# 3               54425                        29993.0
# 4               91660                        51044.0
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                       5.09                                  1.99
# 1                      50.67                                 28.64
# 2                       9.46                                  7.80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 14 columns):
# COUNTRY                                 227 non-null object
# ISO3                                    227 non-null object
# WHO_REGION                              227 non-null object
# DATA_SOURCE                             227 non-null object
# DATE_UPDATED                            227 non-null object
# TOTAL_VACCINATIONS                      227 non-null int64
# PERSONS_VACCINATED_1PLUS_DOSE           220 non-null float64
# TOTAL_VACCINATIONS_PER100               227 non-null float64
# PERSONS_VACCINATED_1PLUS_DOSE_PER100    220 non-null float64
# PERSONS_FULLY_VACCINATED                219 non-null float64
# PERSONS_FULLY_VACCINATED_PER100         219 non-null float64
# VACCINES_USED                           223 non-null object
# FIRST_VACCINE_DATE                      156 non-null object
# NUMBER_VACCINES_TYPES_USED              223 non-null float64
# ...

# %%
df.describe()
# Out:
#        TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count        2.270000e+02                   2.200000e+02
# mean         2.330275e+07                   9.131548e+06
# std          1.449239e+08                   3.880327e+07
# min          7.300000e+01                   0.000000e+00
# 25%          1.283870e+05                   7.461725e+04
# 50%          1.045074e+06                   6.087465e+05
# 75%          7.763394e+06                   4.237226e+06
# max          2.040872e+09                   5.009039e+08
#
#        TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# count                 227.000000                            220.000000
# mean                   68.648282                             37.736182
# std                    52.998231                             27.106529
# min                     0.110000                              0.000000
# 25%                    18.430000                             12.307500
# ...

# %%
df.describe(include="all")
# Out:
#             COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# count           227  227        227         227          227
# unique          227  227          7           2           25
# top     Saint Lucia  ISL       EURO   REPORTING    8/27/2021
# freq              1    1         60         165           63
# mean            NaN  NaN        NaN         NaN          NaN
# std             NaN  NaN        NaN         NaN          NaN
# min             NaN  NaN        NaN         NaN          NaN
# 25%             NaN  NaN        NaN         NaN          NaN
# 50%             NaN  NaN        NaN         NaN          NaN
# 75%             NaN  NaN        NaN         NaN          NaN
# max             NaN  NaN        NaN         NaN          NaN
#
#         TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# count         2.270000e+02                   2.200000e+02
# unique                 NaN                            NaN
# ...

# %%
df.shape
# Out:
# (227, 14)

# %% [markdown]
# # Data cleaning

# %%
col=df.columns

# %% [markdown]
# ## Find missinng values

# %%
for i in col:
    print(df[i].isnull().value_counts())
    print("")
# Out:
# False    227
# Name: COUNTRY, dtype: int64
#
# False    227
# Name: ISO3, dtype: int64
#
# False    227
# Name: WHO_REGION, dtype: int64
#
# False    227
# Name: DATA_SOURCE, dtype: int64
#
# False    227
# Name: DATE_UPDATED, dtype: int64
#
# False    227
# Name: TOTAL_VACCINATIONS, dtype: int64
#
# False    220
# True       7
# Name: PERSONS_VACCINATED_1PLUS_DOSE, dtype: int64
#
# False    227
# Name: TOTAL_VACCINATIONS_PER100, dtype: int64
#
# False    220
# True       7
# Name: PERSONS_VACCINATED_1PLUS_DOSE_PER100, dtype: int64
#
# False    219
# True       8
# Name: PERSONS_FULLY_VACCINATED, dtype: int64
#
# False    219
# True       8
# Name: PERSONS_FULLY_VACCINATED_PER100, dtype: int64
#
# False    223
# True       4
# Name: VACCINES_USED, dtype: int64
#
# False    156
# True      71
# Name: FIRST_VACCINE_DATE, dtype: int64
#
# False    223
# True       4
# Name: NUMBER_VACCINES_TYPES_USED, dtype: int64

# %% [markdown]
# ## Copy dataset

# %%
data=df[['COUNTRY','TOTAL_VACCINATIONS', 'PERSONS_VACCINATED_1PLUS_DOSE',
       'TOTAL_VACCINATIONS_PER100', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100',
       'PERSONS_FULLY_VACCINATED', 'PERSONS_FULLY_VACCINATED_PER100',
       'VACCINES_USED', 'NUMBER_VACCINES_TYPES_USED']].copy()

# %% [markdown]
# # Remove null values

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (213, 9)

# %% [markdown]
# # Verify changes

# %%
col=data.columns
for i in col:
    print(data[i].isnull().value_counts())
    print("")
# Out:
# False    213
# Name: COUNTRY, dtype: int64
#
# False    213
# Name: TOTAL_VACCINATIONS, dtype: int64
#
# False    213
# Name: PERSONS_VACCINATED_1PLUS_DOSE, dtype: int64
#
# False    213
# Name: TOTAL_VACCINATIONS_PER100, dtype: int64
#
# False    213
# Name: PERSONS_VACCINATED_1PLUS_DOSE_PER100, dtype: int64
#
# False    213
# Name: PERSONS_FULLY_VACCINATED, dtype: int64
#
# False    213
# Name: PERSONS_FULLY_VACCINATED_PER100, dtype: int64
#
# False    213
# Name: VACCINES_USED, dtype: int64
#
# False    213
# Name: NUMBER_VACCINES_TYPES_USED, dtype: int64

# %% [markdown]
# # Save Dataset

# %%
data.to_csv("covid_vaccines_.csv")
